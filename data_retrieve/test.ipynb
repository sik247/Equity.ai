# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# The URL of the page you want to scrape
url = "https://valuesider.com/guru/warren-buffett-berkshire-hathaway/portfolio?sort=-percent_portfolio&page=1"
# Send a GET request to the webpage
response = requests.get(url)

# Initialize BeautifulSoup to parse the response content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the container that holds all the rows
container = soup.find('div', class_='guru_table_body')

# Initialize a list to store the scraped data
data = []

# Check if the container is found
if container:
    # Find all row divs within the container
    rows = container.find_all('div', class_='guru_table_row', recursive=False)

    for row in rows:
        # Extract the data from the cells
        cells = row.find_all('div', class_='guru_table_column')
        
        # The structure of the cells would need to be consistent with the webpage for accurate extraction
        if len(cells) > 5:  # Adjust based on the number of columns in the table
            ticker = cells[1].get_text(strip=True)  # Replace indices as needed
            stock = cells[2].get_text(strip=True)
            percent_portfolio = cells[3].get_text(strip=True)
            shares = cells[4].get_text(strip=True)
            reported_price = cells[5].get_text(strip=True)
            
            data.append([ticker, stock, percent_portfolio, shares, reported_price])

    # Convert the list to a DataFrame
    df = pd.DataFrame(data, columns=['Ticker', 'Stock', '% of Portfolio', 'Shares', 'Reported Price'])
df
# Out:
#    Ticker                         Stock % of Portfolio         Shares  \
# 0    AAPL                     APPLE INC         50.19%    905,560,000
# 1     BAC          BANK OF AMERICA CORP         10.01%  1,032,852,006
# 2     AXP           AMERICAN EXPRESS CO          8.18%    151,610,700
# 3      KO              COCA-COLA CO/THE          6.79%    400,000,000
# 4     CVX                  CHEVRON CORP          5.41%    126,093,326
# 5     OXY     OCCIDENTAL PETROLEUM CORP          4.19%    243,715,804
# 6     KHC            KRAFT HEINZ CO/THE          3.47%    325,634,818
# 7     MCO                  MOODY'S CORP          2.77%     24,669,778
# 8     DVA                    DAVITA INC          1.09%     36,095,570
# 9       C         CITIGROUP INC COM NEW          0.82%     55,244,797
# 10   VRSN                  VERISIGN INC          0.76%     12,815,613
# 11     KR                     KROGER CO          0.66%     50,000,000
# 12      V       VISA INC-CLASS A SHARES          0.62%      8,297,460
# 13     MA            MASTERCARD INC - A          0.49%      3,986,648
# 14    COF    CAPITAL ONE FINANCIAL CORP          0.47%     12,471,030
# 15   AMZN                 AMAZONCOM INC          0.44%     10,000,000
# 16   CHTR  CHARTER COMMUNICATIONS INC-A          0.43%      3,828,941
# 17  LSXMK  LIBERTY MEDIA CORP-LIBER-NEW          0.36%     43,208,291
# 18   SNOW         SNOWFLAKE INC-CLASS A          0.35%      6,125,376
# 19    AON               AON PLC-CLASS A          0.34%      4,100,000
#
#    Reported Price
# 0         $192.53
# 1          $33.67
# 2         $187.34
# 3          $58.93
# 4         $149.16
# 5          $59.71
# 6          $36.98
# 7         $390.56
# 8         $104.76
# 9          $51.44
# 10        $205.96
# 11         $45.71
# 12        $260.35
# 13        $426.51
# 14        $131.12
# 15        $151.94
# 16        $388.68
# 17         $28.78
# 18        $199.00
# 19        $291.02
